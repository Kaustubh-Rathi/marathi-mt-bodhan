# %% [markdown]
# # 02 — Train Bodhan Gemma-4 (QLoRA) on Kaggle
#
# Fine-tunes the gated `bodhan-ai/indic-translate` checkpoint
# (Gemma-4 decoder-only) for Hindi→Marathi education-domain MT with 4-bit QLoRA.
# Run cells top to bottom on a Kaggle GPU notebook (Python 3.11).

# %%
# %pip install -q transformers==5.13.1 trl==1.6.0 peft==0.20.0 datasets==5.0.1 tokenizers==0.22.2 accelerate bitsandbytes sentencepiece sacrebleu huggingface_hub PyYAML pandas matplotlib tensorboard

# %%
import os
from kaggle_secrets import UserSecretsClient

os.environ["HF_TOKEN"] = UserSecretsClient().get_secret("HF_TOKEN")
print("HF_TOKEN set:", bool(os.environ.get("HF_TOKEN")))

# %%
import os, sys

if "/kaggle/working/marathi-mt-bodhan/src" not in sys.path:
    sys.path.insert(0, "/kaggle/working/marathi-mt-bodhan/src")
os.chdir("/kaggle/working/marathi-mt-bodhan")
print(os.getcwd())

import torch
print("cuda:", torch.cuda.is_available())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))

# %%
# !PYTHONPATH=src python -m mr_mt.train_bodhan_qlora --config configs/cellA_bodhan_qlora.yaml

# %%
import os

adapter = "/kaggle/working/cellA/adapter"
print(os.listdir(adapter))
